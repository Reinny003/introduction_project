# %%
#import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#prepare data
x=[1,3,5,7,8,9]
y=[10,9,20,11,4,5]

# %%
#setup plot
fig,ax=plt.subplots()
ax.plot(x,y);
ax.set(title="simple plot",
      xlabel="x-axis",
      ylabel="y-axis");
fig.savefig("%save")

# %% [markdown]
# ## Making figures with Numpy arrays

# %%
x_line = np.linspace(0 , 10, 50)
x_line
x_line.shape
# Out:
# (50,)

# %%
fig, ax= plt.subplots()
ax.plot(x_line, x_line**2);

# %%
fig, ax =plt.subplots()
ax.scatter(x_line, np.exp(x_line));

# %%
#making graphs from dictionaries
peanut_butter_prices = {"Home nut":200,
                       "cool butter":350,
                       "smooth nuts":290}
fig, ax =plt.subplots()
ax.bar(peanut_butter_prices.keys(),peanut_butter_prices.values());

# %%
fig, ax =plt.subplots()
ax.barh(list(peanut_butter_prices.keys()),list(peanut_butter_prices.values()));

# %%
fig, ((ax1,ax2), (ax3,ax4))=plt.subplots(nrows=2,
                                        ncols=2,
                                        figsize=(10,5))

ax1.bar(x_line,x_line/2);
ax2.plot(x_line,x_line**2);
ax3.scatter(peanut_butter_prices.keys(),peanut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas DataFrame

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]=car_sales["Price"].str.replace("[\$\,\.]", "", regex=True).astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4   400000.0
# 1   Honda    Red          87899      4   500000.0
# 2  Toyota   Blue          32549      3   700000.0
# 3     BMW  Black          11179      5  2200000.0
# 4  Nissan  White         213095      4   350000.0
# 5  Toyota  Green          99213      4   450000.0
# 6   Honda   Blue          45698      4   750000.0
# 7   Honda   Blue          54738      4   700000.0
# 8  Toyota  White          60000      4   625000.0
# 9  Nissan  White          31600      4   970000.0

# %%
car_sales["Price"].sum()
# Out:
# 7645000.0

# %%
car_sales.plot(y="Odometer (KM)",x="Price",kind="bar");

# %%
car_sales["Price"].dtype
# Out:
# dtype('float64')

# %%
p = np.random.randn(10,4)
df=pd.DataFrame(p,columns=["a","b","c","d"])
df
# Out:
#           a         b         c         d
# 0 -0.018533  1.238094  0.251153 -0.690699
# 1  0.154091  0.033412  0.330563  0.743590
# 2  0.522326  1.650658  0.173096 -0.854553
# 3 -2.377028  0.503285  0.418175  0.716655
# 4  0.486448  0.874719  0.853995  1.438683
# 5  2.248880 -0.223720  0.099230 -0.070121
# 6  0.423598 -1.136630  1.172463  0.252999
# 7 -1.169572 -1.755325 -0.519115 -0.401689
# 8 -0.934015 -1.172173 -0.127717 -0.848583
# 9  1.195207 -0.318436  1.265938  1.367022

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4   400000.0
# 1   Honda    Red          87899      4   500000.0
# 2  Toyota   Blue          32549      3   700000.0
# 3     BMW  Black          11179      5  2200000.0
# 4  Nissan  White         213095      4   350000.0
# 5  Toyota  Green          99213      4   450000.0
# 6   Honda   Blue          45698      4   750000.0
# 7   Honda   Blue          54738      4   700000.0
# 8  Toyota  White          60000      4   625000.0
# 9  Nissan  White          31600      4   970000.0

# %%
car_sales["Odometer (KM)"].plot.hist(bins=25);

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
heart_disease["age"].plot.hist();

# %%
heart_disease.plot.hist(figsize=(10,40),subplots=True);

# %%
heart_disease.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 7    44    1   1       120   263    0        1      173      0      0.0
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# 12   49    1   1       130   266    0        1      171      0      0.6
# 13   64    1   3       110   211    0        0      144      1      1.8
# 14   58    0   3       150   283    1        0      162      0      1.0
# 15   50    0   2       120   219    0        1      158      0      1.6
# 16   58    0   2       120   340    0        1      172      0      0.0
# 17   66    0   3       150   226    0        1      114      0      2.6
# 18   43    1   0       150   247    0        1      171      0      1.5
# 19   69    0   3       140   239    0        1      151      0      1.8
#
#     slope  ca  thal  target
# 0       0   0     1       1
# 1       0   0     2       1
# 2       2   0     2       1
# 3       2   0     2       1
# 4       2   0     2       1
# 5       1   0     1       1
# 6       1   0     2       1
# 7       2   0     3       1
# 8       2   0     3       1
# 9       2   0     2       1
# 10      2   0     2       1
# 11      2   0     2       1
# 12      2   0     2       1
# 13      1   0     2       1
# 14      2   0     2       1
# 15      1   0     2       1
# 16      2   0     2       1
# 17      0   0     2       1
# 18      2   0     2       1
# 19      2   2     2       1

# %%
over_45=heart_disease[heart_disease["age"]>45]
over_45.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# 12   49    1   1       130   266    0        1      171      0      0.6
# 13   64    1   3       110   211    0        0      144      1      1.8
# 14   58    0   3       150   283    1        0      162      0      1.0
# 15   50    0   2       120   219    0        1      158      0      1.6
# 16   58    0   2       120   340    0        1      172      0      0.0
# 17   66    0   3       150   226    0        1      114      0      2.6
# 19   69    0   3       140   239    0        1      151      0      1.8
# 20   59    1   0       135   234    0        1      161      0      0.5
# 23   61    1   2       150   243    1        1      137      1      1.0
# 25   71    0   1       160   302    0        1      162      0      0.4
# 26   59    1   2       150   212    1        1      157      0      1.6
#
#     slope  ca  thal  target
# 0       0   0     1       1
# 3       2   0     2       1
# 4       2   0     2       1
# 5       1   0     1       1
# 6       1   0     2       1
# 8       2   0     3       1
# 9       2   0     2       1
# 10      2   0     2       1
# 11      2   0     2       1
# 12      2   0     2       1
# 13      1   0     2       1
# 14      2   0     2       1
# 15      1   0     2       1
# 16      2   0     2       1
# 17      0   0     2       1
# 19      2   2     2       1
# 20      1   0     3       1
# 23      1   0     2       1
# 25      2   2     2       1
# 26      2   0     2       1

# %%
over_45.plot(kind="scatter",
            y="age",
            x="chol",
            c="target");

# %%
## oo method

# %%
fix, ax=plt.subplots(figsize=(10,6))
over_45.plot(kind="scatter",
            y="age",
            x="chol",
            c="target",
            ax=ax);

# %%
fix,ax=plt.subplots(figsize=(10,6))
scatter=ax.scatter(
                  x=over_45["age"],
                  y=over_45["chol"],
                  c=over_45["target"]);

ax.set(title="ÖVER 45 YEARS CHOLESTROL DATA",
      xlabel="Age",
      ylabel="Cholestrol");

ax.legend(*scatter.legend_elements(), title="target");

ax.axhline(over_45["chol"].mean(),
          linestyle="--");

# %%
fix, (ax0,ax1)=plt.subplots(nrows=1,
                           ncols=2,
                           figsize=(15,8))

ax0.hist(over_45["chol"], bins=20, color='blue', edgecolor='black')
ax0.set(title="Cholesterol Distribution",
        xlabel="Cholesterol",
        ylabel="Frequency")
ax0.axhline(over_45["chol"].mean(),
            linestyle="--",
            color='red',
            label='Mean Cholesterol')
ax0.legend(title="Mean Line");


scatter=ax1.scatter(
                  x=over_45["age"],
                  y=over_45["thalach"],
                  c=over_45["target"]);
ax1.set(title="THALACH DATA",
       xlabel="Age",
       ylabel="thalach");

ax1.legend(*scatter.legend_elements(), title="target");

ax1.axhline(over_45["thalach"].mean(),
            linestyle="--");

fig.suptitle("HEART DISEASE ANALYSIS",fontsize=18,fontweight="bold");

# %%
over_45
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [239 rows x 14 columns]
